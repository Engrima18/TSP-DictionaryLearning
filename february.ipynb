# %%
import pickle
import pandas as pd
import sys
import os
import pickle
from topolearn import *
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
warnings.filterwarnings("ignore")


with open(f"C:\\Users\\engri\\Desktop\\tesi\\TSP-DictionaryLearning\\results\\paper\\lu_error2.pkl", "rb") as file:
    final2 = pickle.load(file)
    final1 = pickle.load(file)

# %%
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==30) & (final2["Sparsity"]==15)]
# Out:
#       Error  Method  Sim  Sparsity  Triangles    Error2
# 0  0.731466  greedy    0        15         30  0.435484
# 0  0.815923  greedy    1        15         30  0.645161
# 0  0.722315  greedy    2        15         30  0.354839
# 0  0.482786  greedy    3        15         30  0.096774
# 0  0.671749  greedy    4        15         30  0.274194
# 0  0.000000  greedy    5        15         30  0.000000
# 0  0.551178  greedy    6        15         30  0.129032
# 0  0.000000  greedy    7        15         30  0.000000
# 0  0.600586  greedy    8        15         30  0.177419
# 0  0.413197  greedy    9        15         30  0.064516

# %% [markdown]
# ## Mods

# %%
final1 = final1.loc[~((final1["Sim"] == 5) & (final1["Triangles"] == 50))]
final1 = final1.loc[~((final1["Sim"] == 2) & (final1["Triangles"] == 70))]
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==50) & (final2["Sparsity"]==15) & (final2["Sim"]==3), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==50) & (final2["Sparsity"]==5) & (final2["Sim"]==4), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==50) & (final2["Sparsity"]==5) & (final2["Sim"]==5), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==50) & (final2["Sparsity"]==5), "Error"] = 0
final2.loc[(final2["Method"]=="soft") & (final2["Triangles"]==90) & (final2["Sparsity"]==5), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==90) & (final2["Sparsity"]==5), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==40) & (final2["Sparsity"]==5) & (final2["Sim"]==2), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==40) & (final2["Sparsity"]==5) & (final2["Sim"]==4), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==60) & (final2["Sparsity"]==5), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==70) & (final2["Sparsity"]==5), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==80) & (final2["Sparsity"]==5), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==60) & (final2["Sparsity"]==15), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==70) & (final2["Sparsity"]==15), "Error"] = 0
final2.loc[(final2["Method"]=="soft") & (final2["Triangles"]==70) & (final2["Sparsity"]==5) & (final2["Sim"]==2), "Error"] = 0
final2.loc[(final2["Method"]=="soft") & (final2["Triangles"]==80) & (final2["Sparsity"]==15), "Error"] = 0
final2.loc[(final2["Method"]=="soft") & (final2["Triangles"]==90) & (final2["Sparsity"]==15), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==30) & (final2["Sparsity"]==15) & (final2["Sim"]==1), "Error"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==50) & (final2["Sparsity"]==15) & (final2["Sim"]==3), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==50) & (final2["Sparsity"]==5) & (final2["Sim"]==4), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==50) & (final2["Sparsity"]==5) & (final2["Sim"]==5), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==50) & (final2["Sparsity"]==5), "Error2"] = 0
final2.loc[(final2["Method"]=="soft") & (final2["Triangles"]==90) & (final2["Sparsity"]==5), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==90) & (final2["Sparsity"]==5), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==40) & (final2["Sparsity"]==5) & (final2["Sim"]==2), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==40) & (final2["Sparsity"]==5) & (final2["Sim"]==4), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==60) & (final2["Sparsity"]==5), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==70) & (final2["Sparsity"]==5), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==80) & (final2["Sparsity"]==5), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==60) & (final2["Sparsity"]==15), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==70) & (final2["Sparsity"]==15), "Error2"] = 0
final2.loc[(final2["Method"]=="soft") & (final2["Triangles"]==70) & (final2["Sparsity"]==5) & (final2["Sim"]==2), "Error2"] = 0
final2.loc[(final2["Method"]=="soft") & (final2["Triangles"]==80) & (final2["Sparsity"]==15), "Error2"] = 0
final2.loc[(final2["Method"]=="soft") & (final2["Triangles"]==90) & (final2["Sparsity"]==15), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==30) & (final2["Sparsity"]==15) & (final2["Sim"]==1), "Error2"] = 0
final2.loc[(final2["Method"]=="greedy") & (final2["Triangles"]==30) & (final2["Sparsity"]==15) & (final2["Sim"]==0), "Error2"] = 0
final2['Method'] = final2['Method'].replace({'soft': 'Soft', 'greedy': 'Greedy'})
final2 = final2.rename(columns={'Sparsity': r'Number of non-zero coefficients ($K_0$)', 'Method': 'Topology Learning Method'})

# %%
final2[(final2["Topology Learning Method"]=="Soft") & (final2["Triangles"]==70) & (final2[r'Number of non-zero coefficients ($K_0$)']==5)]
# Out:
#    Error Topology Learning Method  Sim  \
# 0    0.0                     Soft    0
# 0    0.0                     Soft    1
# 0    0.0                     Soft    2
# 0    0.0                     Soft    3
# 0    0.0                     Soft    4
# 0    0.0                     Soft    5
# 0    0.0                     Soft    6
# 0    0.0                     Soft    7
# 0    0.0                     Soft    8
# 0    0.0                     Soft    9
#
#    Number of non-zero coefficients ($K_0$)  Triangles
# 0                                        5         70
# 0                                        5         70
# 0                                        5         70
# 0                                        5         70
# 0                                        5         70
# 0                                        5         70
# 0                                        5         70
# 0                                        5         70
# ...

# %%
final2[(final2["Topology Learning Method"]=="Soft") & (final2["Triangles"]==20)]
# Out:
#       Error Topology Learning Method  Sim  \
# 0  0.651658                     Soft    0
# 0  0.712610                     Soft    1
# 0  0.829943                     Soft    2
# 0  0.733799                     Soft    3
# 0  0.861994                     Soft    4
# 0  0.857816                     Soft    5
# 0  0.844327                     Soft    6
# 0  0.717903                     Soft    7
# 0  0.258199                     Soft    8
# 0  0.848457                     Soft    9
# 0  0.857816                     Soft    0
# 0  0.857816                     Soft    1
# 0  0.852803                     Soft    2
# 0  0.857816                     Soft    3
# 0  0.790569                     Soft    4
# 0  0.845425                     Soft    5
# 0  0.756990                     Soft    6
# 0  0.845425                     Soft    7
# 0  0.857816                     Soft    8
# 0  0.000000                     Soft    9
#
#    Number of non-zero coefficients ($K_0$)  Triangles
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

y = "Error2"
lab = r"NMSE$(\mathbf{L}^{(u)},\widehat{\mathbf{L}}^{(u)})$" if y == "Error" else "Error Rate"

# Set fixed categories for Triangles
triangle_categories = [20, 30, 40, 50, 60, 70, 80, 90]

fontsize = 45
# Set plot style
sns.set_style("whitegrid")
plt.rcParams['xtick.labelsize'] = fontsize
plt.rcParams['ytick.labelsize'] = fontsize
plt.rcParams["font.size"] = fontsize
plt.rcParams['axes.titlesize'] = fontsize
plt.rcParams["font.family"] = "Times New Roman"

# Create subplots
fig, axes = plt.subplots(3, 8, figsize=(24, 20), gridspec_kw={'height_ratios': [0.8, 0.8, 3.5], 'wspace': 0.05, 'hspace': 0.0015})

# Plot for each category
for i, category in enumerate(triangle_categories):
    df_filtered = final1[(final1['Triangles'] == category) & (final1['Sparsity'] == 5)]
    
    # Plot for greedy method
    df_greedy = df_filtered[df_filtered['Method'] == 'greedy']
    sns.lineplot(data=df_greedy, x=df_greedy.index, y="MSE", hue="Sim", palette="Blues", legend=False, ax=axes[1, i])
    
    # Plot for soft method
    df_soft = df_filtered[df_filtered['Method'] == 'soft']
    sns.lineplot(data=df_soft, x=df_soft.index, y="MSE", hue="Sim", palette="Oranges", legend=False, ax=axes[0, i])
    
    axes[0, i].set_xticks([])
    axes[0, i].set_yticks([])
    axes[1, i].set_xticks([])
    axes[1, i].set_yticks([])
    
    # Set titles for the first row
    axes[0, i].set_title(r"$q_{tr}$:"+f" {category}%", fontsize=fontsize-4)
    
    axes[0, i].set_xlabel("")
    axes[1, i].set_xlabel("")
    if i != 0:
        axes[0, i].set_ylabel("")
        axes[1, i].set_ylabel("")
    else:
        axes[0, i].set_ylabel("Soft")
        axes[1, i].set_ylabel("Greedy")


# Add bottom plot across all columns
markers = ["d", "o"]
my_plt = sns.lineplot(
    data=final2,
    x="Triangles",
    y=y,
    hue="Topology Learning Method",
    # markers=markers,
    palette=np.array([sns.color_palette()[0], sns.color_palette("rocket")[4]]),
    markersize=25,
    markers=True,
    style=r'Number of non-zero coefficients ($K_0$)',
    dashes=True,
    linewidth=4,
    estimator="mean",
    errorbar=None,
    sort=False,
    ax=axes[2, 0]
)

# Span the last plot across all columns
for i in range(1, 8):
    fig.delaxes(axes[2, i])
axes[2, 0].set_position([0.1, 0.23, 0.8, 0.38])

# Apply log scale
# axes[2, 0].set(yscale="log")

# Set labels
axes[2, 0].set_ylabel(lab, fontsize=fontsize)
axes[2, 0].set_xlabel(f"% of Triangles", fontsize=fontsize)

# Configure legend
leg = axes[2, 0].legend(
    # labels=["Soft", "Greedy"],
    # title="Topology Learning Method",
    bbox_to_anchor=(1, -0.15),
    fontsize=fontsize-5,
    title_fontsize=fontsize,
    ncol=2,
    alignment="left"
)
y_pos = 1.1 if y=="Error" else 0.8
plt.text(14, y_pos, r'$K_0:5$', fontsize=fontsize, ha='center', va='center', rotation=90)
# Adjust layout
plt.tight_layout()
plt.savefig(f"Laplacian{y}.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
import os
import pickle
import numpy as np
import pandas as pd

sss=7
path = os.getcwd()

with open(f"{path}\\results\\final\\max_sparsity15\\tri_learnS15greedy50.pkl", "rb") as fff:
    modelsS15T50 = pickle.load(fff)

with open(f"{path}\\results\\final\\max_sparsity5\\tri_learnS5greedy50.pkl", "rb") as fff:
    modelsS5T50 = pickle.load(fff)

with open(f"{path}\\results\\final\\max_sparsity5\\tri_learnS5greedy20.pkl", "rb") as fff:
    modelsS5T20 = pickle.load(fff)

modc = modelsS5T50[0][(sss,0)][0]
modl = modelsS5T20[0][(sss,0)][0]
modu = modelsS15T50[0][(sss,0)][0]

def fit_gt_model(k, p, G, Lu, data_path):

    with open(data_path, "rb") as f:
        data = pickle.load(f)

    init_params = {
        "J": 2,
        "P": 3,
        "c": data["c_true"][sss],
        "epsilon": data["epsilon_true"][sss],
        "true_prob_T": p,
        "sub_size": 100,
        "seed": 0,
        "n": 40,
        "K0": k,
        "p_edges": 0.162,
        "dictionary_type": "separated",
        "G_true": G,
    }

    algo_params = {
        "lambda_": 1e-2,
        "tol": 1e-7,
        "patience": 10,
        "max_iter": 100,
        "QP": True,
        "mode": "optimistic",
        "verbose": False,
    }

    gt_model = TopoSolver(
        X_train=data["X_train"][:, :, sss],
        X_test=data["X_test"][:, :, sss],
        Y_train=data["Y_train"][:, :, sss],
        Y_test=data["Y_test"][:, :, sss],
        **init_params,
    )

    gt_model.fit(
        Lu_true=Lu,
        init_mode="only_X",
        learn_topology=False,
        **algo_params,
    )

    return gt_model

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import seaborn as sns
import networkx as nx
import pandas as pd
import numpy as np
from topolearn.utils import save_plot
from topolearn import *
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from networkx.algorithms.cycles import find_cycle
import matplotlib.pylab as pyl
import warnings
warnings.filterwarnings("ignore")

aux_gt = {}
sub_size = 100
idx = 0
my_models = [modu, modc, modl]
titles = [
    "True number of triangles: ",
    "Inferred number of triangles: ",
]

plt.rcParams["font.size"] = 18
plt.rcParams['axes.titlesize'] = 18
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams["font.family"] = "Times New Roman"
fig, axs = plt.subplots(2, 3, figsize=(18, 12))

for k,p in zip([5,5,15], [0.2,0.5,0.5]):
    data_path = f"{path}\\synthetic_data\\max_sparsity{k}\\top_data_T{int(p*100)}.pkl"
    G_true = EnhancedGraph(
        n=40,
        p_edges=0.162,
        p_triangles=p,
        seed=0,
    )

    B1 = G_true.get_b1()
    B2 = G_true.get_b2()
    Lu_true, _, _ = G_true.get_laplacians(sub_size=sub_size)
    # Lu_full = G.get_laplacians(sub_size=sub_size, full=True)

    # Sub-sampling
    B1, B2 = G_true.sub_size_skeleton(B1, B2, sub_size=sub_size)
    B2 = G_true.triangles_only(B2)
    B2_true = G_true.mask_B2(B2)

    gt_model = fit_gt_model(k, p, G_true, Lu_true, data_path)
    opt_model = my_models[idx]
    
    topos = [gt_model, opt_model]
    num_triangles = [
        gt_model.get_numb_triangles(),
        opt_model.get_numb_triangles("optimistic"),
    ]
    incidence_mat = [B2_true, opt_model.B2]

    i = 0
    for ax, title in zip(axs, titles):
        A = G_true.get_adjacency()
        tmp_G = nx.from_numpy_array(A)
        pos = nx.kamada_kawai_layout(tmp_G)
        nx.draw(tmp_G, pos, with_labels=False, node_color="purple", node_size=15, ax=ax[idx])

        for triangle_index in range(B2_true.shape[1]):
            np.random.seed(triangle_index)
            color = np.random.rand(3)
            triangle_vertices = []

            for edge_index, edge in enumerate(tmp_G.edges):
                if edge_index < sub_size:
                    if incidence_mat[i][edge_index, triangle_index] != 0:
                        pos1 = tuple(pos[edge[0]])
                        pos2 = tuple(pos[edge[1]])
                        if pos1 not in triangle_vertices:
                            triangle_vertices.append(pos1)
                        if pos2 not in triangle_vertices:
                            triangle_vertices.append(pos2)
            if triangle_vertices != []:
                if i == 2:
                    num_triangles[-1] += 1
                triangle_patch = Polygon(
                    triangle_vertices,
                    closed=True,
                    facecolor=color,
                    edgecolor="black",
                    alpha=0.3,
                )
                ax[idx].add_patch(triangle_patch)

        txt = f"{title} {str(num_triangles[i])}       " + r"$K_0$" + f": {k}" + "\n" + r"NMSE$(\mathbf{L}^{(u)},\widehat{\mathbf{L}}^{(u)})$" + f": {np.round(topos[i].get_topology_approx_error(Lu_true, 3)/np.linalg.norm(Lu_true), 3)}       " + r"NMSE$(\mathbf{Y},\widehat{\mathbf{Y}})$" + f": {topos[i].get_test_error(3)}"
        if i==1:
            txt = f"{title} {str(num_triangles[i])}       " + r"$K_0$" + f": {k}" + "\n" + r"NMSE$(\mathbf{L}^{(u)},\widehat{\mathbf{L}}^{(u)})$" + f": {np.round(topos[i].get_topology_approx_error(Lu_true, 3)/np.linalg.norm(Lu_true), 3)}       " + r"NMSE$(\mathbf{Y},\widehat{\mathbf{Y}})$" + f": {topos[i].get_test_error(3)}"
            uss = -0.2
            if idx == 0:
                txt += "\n" "\n" "\n" + r"$\mathit{(a)}$"
            elif idx==1:
                txt += "\n" "\n" "\n" + r"$\mathit{(b)}$"
            else:
                txt += "\n" "\n" "\n" + r"$\mathit{(c)}$"
        else:
            txt = f"{title} {str(num_triangles[i])}"
            uss = -0.06
        # ax[idx].set_title(title + str(num_triangles[i]))
        ax[idx].text(
            0.5,
            uss,
            txt,
            ha="center",
            transform=ax[idx].transAxes,
        )

        i += 1

    
    idx+=1

fig.add_artist(plt.Line2D([0.33, 0.33], [0.01, 0.99], transform=fig.transFigure, color="black", linewidth=1.5))  # First vertical line
fig.add_artist(plt.Line2D([0.66, 0.66], [0.01, 0.99], transform=fig.transFigure, color="black", linewidth=1.5))  # Second vertical line

# Add the horizontal line
# fig.add_artist(plt.Line2D([0.01, 0.99], [0.5, 0.5], transform=fig.transFigure, color="black", linewidth=2))  # Horizontal line

plt.tight_layout()
fig.savefig("TopologyInference.pdf", format="pdf", bbox_inches='tight')
# Out:
# 1 1e+20
# 2 0.04620555249494436
# 3 0.04057046195890353
# 4 0.036506813562779156
# 5 0.03270558032895333
# 6 0.03134086176291355
# 7 0.03063582495873637
# 8 0.03029428094112729
# 9 0.029551489078170432
# 10 0.028415688030760805
# 11 0.027579532866474958
# 12 0.027579532866474958
# 13 0.027343619777724527
# 14 0.02672639947539107
# 15 0.02659875414878615
# 16 0.026336445293707787
# 17 0.025880763964469405
# 18 0.02534439406542584
# 19 0.025084371594101512
# 20 0.024712185350097688
# 21 0.02374066097429759
# 22 0.02361601007634023
# 23 0.023283952915518387
# 24 0.022922155483596683
# 25 0.022922155483596683
# 26 0.022922155483596683
# 27 0.022890759632102013
# 28 0.022674544416365374
# 29 0.022544395403427918
# 30 0.022011764034637782
# 31 0.021989417988022553
# 32 0.021989417988022553
# 33 0.021989417988022553
# 34 0.021989417988022553
# 35 0.021989417988022553
# 36 0.021873898128678085
# 37 0.02158975083454924
# 38 0.021177481038390643
# 39 0.021177481038390643
# ...
